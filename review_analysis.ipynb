# %%
import pandas as pd
from pandas import DataFrame
from pandas import Series
import numpy as np

df = pd.read_csv("output_.csv")

# %%
df
# Out:
#          type category                                             review  \
# 0     에어팟 1세대       음질  2세대로 배송 받았고 철가루랑 하얀색 실리콘케이스도 잘 받았습니다 역시 사용해보니 ...
# 1     에어팟 1세대       음질  배송은 4시 이전 주문 당일 발송으로 다음날 바로 받았구요, 바로 정품 등록했는데 ...
# 2     에어팟 1세대       음질  아이폰과 아이패드를 둘 다 사용하고 있는데 아이폰에서 음악을 듣거나 영상을 보다 아...
# 3     에어팟 1세대       음질  다른 저렴한 곳도 있었습니다.\n\n그래도 제조일자 최신에 페이백으로 다시 받는 금...
# 4     에어팟 1세대       음질  택배도 하루일찍오고 하자 하나도 없고 깔끔했어요 뽁뽁이로 포장도 해주셔서 너무 감사...
# ...       ...      ...                                                ...
# 3679  에어팟 2세대      착용감                    생각 보다 착용감이 좋습니다. 즐거운 사운드를 느꼈습니다
# 3680  에어팟 2세대      착용감  우선 이전에 에어팟을 써본적은 없고 갤럭시 기어 아이콘 2018년 형을 썼는데 에어...
# 3681  에어팟 2세대      휴대성  휴대하기 편하고, 애플 기기 사이의 호환성이 좋은 무선 이어폰이 필요해서 에어팟을 ...
# 3682  에어팟 2세대      휴대성               휴대하기도 좋고 음질도 좋은데 떨어져서 잊어 버릴까 불안 하네요~
# 3683  에어팟 2세대      휴대성                           디자인도 깔끔하니 세련되고 휴대성도 좋아요~
#
#       star
# 0        5
# 1        5
# 2        5
# 3        4
# 4        5
# ...    ...
# 3679     5
# 3680     5
# 3681     4
# 3682     4
# 3683     5
#
# [3684 rows x 4 columns]

# %% [markdown]
# # 빈도분석 결과를 추가한 단어 사전을 이용한 감성분석

# %% [markdown]
# 토큰화 된 리뷰를 불러와서 단어 사전에 대해 감성 분석을 진행한 후, 긍정도 부정도를 추가하여 df를 생성한다.
#
#
# 생성한 df에 대하여 카테고리 별 (statistics1), 별점 별(statistics3) 긍/부정도 분석진행

# %%
import pandas as pd
from pandas import DataFrame
from pandas import Series
import numpy as np

df2 = pd.read_csv("token_output.csv")

# %%
df2
# Out:
#          type category                                             review  \
# 0     에어팟 1세대       음질  2세대로 배송 받았고 철가루랑 하얀색 실리콘케이스도 잘 받았습니다 역시 사용해보니 ...
# 1     에어팟 1세대       음질  배송은 4시 이전 주문 당일 발송으로 다음날 바로 받았구요, 바로 정품 등록했는데 ...
# 2     에어팟 1세대       음질  아이폰과 아이패드를 둘 다 사용하고 있는데 아이폰에서 음악을 듣거나 영상을 보다 아...
# 3     에어팟 1세대       음질  다른 저렴한 곳도 있었습니다.\n\n그래도 제조일자 최신에 페이백으로 다시 받는 금...
# 4     에어팟 1세대       음질  택배도 하루일찍오고 하자 하나도 없고 깔끔했어요 뽁뽁이로 포장도 해주셔서 너무 감사...
# ...       ...      ...                                                ...
# 3679  에어팟 2세대      착용감                    생각 보다 착용감이 좋습니다. 즐거운 사운드를 느꼈습니다
# 3680  에어팟 2세대      착용감  우선 이전에 에어팟을 써본적은 없고 갤럭시 기어 아이콘 2018년 형을 썼는데 에어...
# 3681  에어팟 2세대      휴대성  휴대하기 편하고, 애플 기기 사이의 호환성이 좋은 무선 이어폰이 필요해서 에어팟을 ...
# 3682  에어팟 2세대      휴대성               휴대하기도 좋고 음질도 좋은데 떨어져서 잊어 버릴까 불안 하네요~
# 3683  에어팟 2세대      휴대성                           디자인도 깔끔하니 세련되고 휴대성도 좋아요~
#
#       star                                       token_review
# 0        5  ['2', '세대', '로', '배송', '받았고', '철', '가루', '랑', ...
# 1        5  ['배송', '은', '4시', '이전', '주문', '당일', '발송', '으로'...
# 2        5  ['아이폰', '과', '아이패드', '를', '둘', '다', '사용', '하고'...
# 3        4  ['다른', '저렴한', '곳도', '있었습니다', '\n\n', '그래도', '제...
# 4        5  ['택배', '도', '하루', '일찍', '오고', '하자', '하나', '도',...
# ...    ...                                                ...
# 3679     5  ['생각', '보다', '착용', '감', '이', '좋습니다', '즐거운', '사...
# 3680     5  ['우선', '이전', '에', '에어팟', '을', '써', '본적', '은', ...
# 3681     4  ['휴대', '하기', '편하고', '애플', '기기', '사이', '의', '호환...
# 3682     4  ['휴대', '하기도', '좋고', '음질', '도', '좋은데', '떨어져서', ...
# 3683     5    ['디자인', '도', '깔끔하니', '세련되고', '휴대', '성도', '좋아요']
#
# [3684 rows x 5 columns]

# %%
import os
import csv
import re
import numpy as np
import pandas as pd
from math import log
import warnings
warnings.filterwarnings("ignore")

from konlpy.tag import Hannanum
hn = Hannanum()


os.getcwd()

os.chdir(r'C:\Users\jmlee\Desktop\4학년 1학기\텍스트마이닝을 이용한 소비자분석\프로젝트_naver_crawling')
docs=df2['token_review']
N=len(docs)
#remove carriage return
def cleancr(dic):
    line = []
    for i in range(len(dic)):
        line.append(re.sub("\s", "", dic[i]))
    return line

#count matches
def matches(dic, d):
    return d.count(dic)

#긍부정어 사전 로딩
f = open("positive.txt", 'r', encoding='UTF8')
positive = f.readlines()
f.close()
positive = cleancr(positive)

f = open("negative.txt", 'r', encoding='UTF8')
negative = f.readlines()
f.close()
negative = cleancr(negative)

#사전비교
N = len(docs)

res = np.zeros(shape=(N, 2), dtype = np.int8)
for i in range(N): #문서별로 수행
    d = docs[i]
    cnt = 0
    for j in range(len(positive)):
        dic = positive[j]        
        cnt += matches(dic, d)
    res[i, 0] = cnt

for i in range(N): #문서별로 수행
    d = docs[i]
    cnt = 0
    for j in range(len(negative)):
        dic = negative[j]        
        cnt += matches(dic, d)
    res[i, 1] = cnt
    
    
positive=[]
for i in range(N):
    res
    pos_rate = res[:, 0] / (res[:, 0] + res[:, 1])  #긍정도 계산
    positive.append(pos_rate) #하나의 리스트를 만들어서 한번에 df에 추가해야함.
    df2['positive']=pos_rate #형태소단위로 나누어진 리뷰저장

# %%
df3=df2.drop(df2.columns[2], axis='columns')
df3
# Out:
#          type category  star  \
# 0     에어팟 1세대       음질     5
# 1     에어팟 1세대       음질     5
# 2     에어팟 1세대       음질     5
# 3     에어팟 1세대       음질     4
# 4     에어팟 1세대       음질     5
# ...       ...      ...   ...
# 3679  에어팟 2세대      착용감     5
# 3680  에어팟 2세대      착용감     5
# 3681  에어팟 2세대      휴대성     4
# 3682  에어팟 2세대      휴대성     4
# 3683  에어팟 2세대      휴대성     5
#
#                                            token_review  positive
# 0     ['2', '세대', '로', '배송', '받았고', '철', '가루', '랑', ...  0.800000
# 1     ['배송', '은', '4시', '이전', '주문', '당일', '발송', '으로'...  0.782609
# 2     ['아이폰', '과', '아이패드', '를', '둘', '다', '사용', '하고'...  0.705882
# 3     ['다른', '저렴한', '곳도', '있었습니다', '\n\n', '그래도', '제...  0.411765
# 4     ['택배', '도', '하루', '일찍', '오고', '하자', '하나', '도',...  0.515152
# ...                                                 ...       ...
# 3679  ['생각', '보다', '착용', '감', '이', '좋습니다', '즐거운', '사...  1.000000
# 3680  ['우선', '이전', '에', '에어팟', '을', '써', '본적', '은', ...  0.571429
# 3681  ['휴대', '하기', '편하고', '애플', '기기', '사이', '의', '호환...  0.454545
# 3682  ['휴대', '하기도', '좋고', '음질', '도', '좋은데', '떨어져서', ...  0.545455
# 3683    ['디자인', '도', '깔끔하니', '세련되고', '휴대', '성도', '좋아요']  1.000000
#
# [3684 rows x 5 columns]

# %% [markdown]
# # 전체 데이터 기초 통계

# %%
#if df.loc[(df['type'] != "에어팟 1세대")]:
#에어팟 2세대 유,무선을 에어팟 2세대로 통합
df3['type'] = np.where(df3['type'] != "에어팟 1세대", "에어팟 2세대" , df3['type'])

df3
# Out:
#          type category  star  \
# 0     에어팟 1세대       음질     5
# 1     에어팟 1세대       음질     5
# 2     에어팟 1세대       음질     5
# 3     에어팟 1세대       음질     4
# 4     에어팟 1세대       음질     5
# ...       ...      ...   ...
# 3679  에어팟 2세대      착용감     5
# 3680  에어팟 2세대      착용감     5
# 3681  에어팟 2세대      휴대성     4
# 3682  에어팟 2세대      휴대성     4
# 3683  에어팟 2세대      휴대성     5
#
#                                            token_review  positive
# 0     ['2', '세대', '로', '배송', '받았고', '철', '가루', '랑', ...  0.800000
# 1     ['배송', '은', '4시', '이전', '주문', '당일', '발송', '으로'...  0.782609
# 2     ['아이폰', '과', '아이패드', '를', '둘', '다', '사용', '하고'...  0.705882
# 3     ['다른', '저렴한', '곳도', '있었습니다', '\n\n', '그래도', '제...  0.411765
# 4     ['택배', '도', '하루', '일찍', '오고', '하자', '하나', '도',...  0.515152
# ...                                                 ...       ...
# 3679  ['생각', '보다', '착용', '감', '이', '좋습니다', '즐거운', '사...  1.000000
# 3680  ['우선', '이전', '에', '에어팟', '을', '써', '본적', '은', ...  0.571429
# 3681  ['휴대', '하기', '편하고', '애플', '기기', '사이', '의', '호환...  0.454545
# 3682  ['휴대', '하기도', '좋고', '음질', '도', '좋은데', '떨어져서', ...  0.545455
# 3683    ['디자인', '도', '깔끔하니', '세련되고', '휴대', '성도', '좋아요']  1.000000
#
# [3684 rows x 5 columns]

# %%
#5점, 0.8이상 긍정도
five_star=df3[((df3['star']==5)&(df3['positive']>=0.8))][['type','category','star','token_review','positive']]
five_star
# Out:
#          type category  star  \
# 0     에어팟 1세대       음질     5
# 12    에어팟 1세대       음질     5
# 26    에어팟 1세대       음질     5
# 28    에어팟 1세대       음질     5
# 47    에어팟 1세대       음질     5
# ...       ...      ...   ...
# 3672  에어팟 2세대      착용감     5
# 3674  에어팟 2세대      착용감     5
# 3676  에어팟 2세대      착용감     5
# 3679  에어팟 2세대      착용감     5
# 3683  에어팟 2세대      휴대성     5
#
#                                            token_review  positive
# 0     ['2', '세대', '로', '배송', '받았고', '철', '가루', '랑', ...  0.800000
# 12    ['좀', '더', '일찍', '살것을', '전', '인강', '용', '으로', ...  1.000000
# 26    ['배송', '도', '12일', '만에', '와', '굉장히', '빨랐고', '제...  0.818182
# 28    ['얼머전', '에', '에어팟', '구매', '하고', '신세계', '를', '맛...  0.833333
# 47    ['주문', '하고', '이틀', '만에', '왔습니다', '배송', '완료', '...  0.833333
# ...                                                 ...       ...
# 3672  ['뱅앤울룹슨', 'E', '8', '을', '사용', '했었습니다', 'E', '...  0.800000
# 3674         ['착용', '감도', '좋고', '정품', '이라', '더', '좋아요']  1.000000
# 3676  ['배송', '엄청', '빨리', '왔네요', '무선', '이라', '엄청', '편...  1.000000
# 3679  ['생각', '보다', '착용', '감', '이', '좋습니다', '즐거운', '사...  1.000000
# 3683    ['디자인', '도', '깔끔하니', '세련되고', '휴대', '성도', '좋아요']  1.000000
#
# [1737 rows x 5 columns]

# %%
#4점.0.6~0.8긍정도
four_star=df3[((df3['star']==4)&(0.6<=df3['positive'])&(df3['positive']<=0.8))][['type','category','star','token_review','positive']]
four_star
# Out:
#          type category  star  \
# 11    에어팟 1세대       음질     4
# 52    에어팟 1세대       음질     4
# 87    에어팟 1세대       음질     4
# 125   에어팟 1세대       음질     4
# 136   에어팟 1세대       음질     4
# ...       ...      ...   ...
# 3521  에어팟 2세대       품질     4
# 3532  에어팟 2세대       품질     4
# 3542  에어팟 2세대       품질     4
# 3576  에어팟 2세대       성능     4
# 3631  에어팟 2세대      디자인     4
#
#                                            token_review  positive
# 11    ['이', '곳', '저', '곳', '보다가', '하이마트', '조건', '이',...  0.789474
# 52    ['생각', '보다', '귀', '에서', '쉬', '게', '빠지지', '않고',...  0.631579
# 87    ['배송', '꼼꼼하게', '잘', '보내주셨고', '상품', '도', '하자', ...  0.800000
# 125   ['음질', '도', '상태', '도', '다', '좋', '습', '니당', '빠...  0.750000
# 136               ['너무', '좋네요', '음질', '도', '좋고', '편해요']  0.750000
# ...                                                 ...       ...
# 3521  ['저렴한', '가격', '으로', '잘', '샀고', '통화', '랑', '오디오...  0.769231
# 3532  ['하루', '만에', '우체국', '으로', '쏴주네요', '이리저리', '할인'...  0.600000
# 3542                          ['품질', '간편', '최상', '입니다']  0.666667
# 3576  ['가격', '이', '좀', '비싸지만', '성능', '디자인', '모두', '좋...  0.714286
# 3631  ['예쁘고', '좋습니다', '\n', '소리', '도', '잘', '들리고', '...  0.714286
#
# [165 rows x 5 columns]

# %%
#3점. 0.4~0.6 긍정도
three_star=df3[((df3['star']==3)&(0.4<=df3['positive'])&(df3['positive']<=0.6))][['type','category','star','token_review','positive']]
three_star
# Out:
#          type category  star  \
# 36    에어팟 1세대       음질     3
# 81    에어팟 1세대       음질     3
# 213   에어팟 1세대       음질     3
# 324   에어팟 1세대       음질     3
# 719   에어팟 1세대       성능     3
# 800   에어팟 1세대       성능     3
# 1024  에어팟 1세대      디자인     3
# 1205  에어팟 2세대       음질     3
# 1594  에어팟 2세대       음질     3
# 1650  에어팟 2세대       음질     3
# 1975  에어팟 2세대       음질     3
# 2224  에어팟 2세대       음질     3
# 2403  에어팟 2세대       품질     3
# 2627  에어팟 2세대       품질     3
# 2757  에어팟 2세대       성능     3
# 3004  에어팟 2세대      디자인     3
# 3219  에어팟 2세대      디자인     3
# 3501  에어팟 2세대       음질     3
# 3675  에어팟 2세대      착용감     3
#
#                                            token_review  positive
# 36    ['이어폰', '도', '분실', '했고', '차량', '용', '블루투스', '도...  0.400000
# 81    ['아이폰', '사용자', '여서', '이어폰', '잭', '이', '없어', '충...  0.500000
# 213   ['믿고', '쓰는', '애플사', '하지만', '음악', '을', '들을', '때...  0.571429
# 324   ['한쪽', '이', '느리게', '인식', '됨', '배송', '은', '빨랐음'...  0.428571
# 719   ['아이폰', '사용자', '여서', '이어폰', '잭', '이', '없어', '충...  0.500000
# 800   ['디자인', '은', '별', '로데', '성능', '은', '생각', '보다',...  0.500000
# 1024  ['디자인', '은', '별', '로데', '성능', '은', '생각', '보다',...  0.500000
# 1205  ['배송', '은', '하루', '만에', '도착', '해서', '너무', '좋았어...  0.562500
# 1594   ['음질', '은', '좋아요', '철', '가루', '가', '너무', '생기네요']  0.600000
# 1650  ['I', '은것', '같아요', '연결', '도', '자동', '으로', '잘',...  0.500000
# 1975  ['빠른', '배송', '음질', '좋고', '통화', '음질', '은', '너무'...  0.466667
# 2224  ['음질', '이', '너무', '너무', '좋아여', '추천', '해주리', '고...  0.500000
# 2403  ['상품', '품질', '과', '배송', '속도', '는', '매우', '만족스럽...  0.583333
# 2627  ['사용', '한지', '한', '달도', '안되었는데', '벌써', '한쪽', '...  0.500000
# 2757  ['성능', '은', '좋아요', '가격', '이', '넘', '비싼것', '같아요...  0.500000
# 3004  ['잘', '받았습니다', '배송', '빨라요', '배송', '빨라', '놀랐어요'...  0.500000
# 3219  ['갤럭시', '노트', '9', '랑', '쓰는데', '자동', '연결', '이'...  0.454545
# 3501  ['근데', '터치', '잘', '안되고', '구린것', '가타', '여', '\n...  0.500000
# 3675  ['아이폰', '을', '쓰고있어서', '기존', '에는', '엘지', '꺼', '...  0.500000

# %%
#2점. 0.2~0.4 긍정도
two_star=df3[((df3['star']==2)&(0.2<=df3['positive'])&(df3['positive']<=0.4))][['type','category','star','token_review','positive']]
two_star
# Out:
# Empty DataFrame
# Columns: [type, category, star, token_review, positive]
# Index: []

# %%
#1점. 0.2이하 긍정도
one_star=df3[((df3['star']==1)&(0.2>=df3['positive']))][['type','category','star','token_review','positive']]
one_star
# Out:
#          type category  star  \
# 2393  에어팟 2세대       품질     1
# 2589  에어팟 2세대       품질     1
# 2612  에어팟 2세대       품질     1
# 3395  에어팟 2세대       음질     1
#
#                                            token_review  positive
# 2393  ['오프라인', '매장', '이나', '애플스토어', '에서', '산', '게', ...  0.181818
# 2589  ['기기', '결함', '이', '있어', '교환', '신청', '했는데', '배송...  0.125000
# 2612                ['유격', '도', '있고', '때', '도', '묻어있네']  0.000000
# 3395  ['새', '리퍼제품', '이라고', '살때', '는', '확인', '을', '못'...  0.200000

# %%
#전체
add_df= pd.concat([five_star,four_star,three_star,two_star,one_star])
add_df
# Out:
#          type category  star  \
# 0     에어팟 1세대       음질     5
# 12    에어팟 1세대       음질     5
# 26    에어팟 1세대       음질     5
# 28    에어팟 1세대       음질     5
# 47    에어팟 1세대       음질     5
# ...       ...      ...   ...
# 3675  에어팟 2세대      착용감     3
# 2393  에어팟 2세대       품질     1
# 2589  에어팟 2세대       품질     1
# 2612  에어팟 2세대       품질     1
# 3395  에어팟 2세대       음질     1
#
#                                            token_review  positive
# 0     ['2', '세대', '로', '배송', '받았고', '철', '가루', '랑', ...  0.800000
# 12    ['좀', '더', '일찍', '살것을', '전', '인강', '용', '으로', ...  1.000000
# 26    ['배송', '도', '12일', '만에', '와', '굉장히', '빨랐고', '제...  0.818182
# 28    ['얼머전', '에', '에어팟', '구매', '하고', '신세계', '를', '맛...  0.833333
# 47    ['주문', '하고', '이틀', '만에', '왔습니다', '배송', '완료', '...  0.833333
# ...                                                 ...       ...
# 3675  ['아이폰', '을', '쓰고있어서', '기존', '에는', '엘지', '꺼', '...  0.500000
# 2393  ['오프라인', '매장', '이나', '애플스토어', '에서', '산', '게', ...  0.181818
# 2589  ['기기', '결함', '이', '있어', '교환', '신청', '했는데', '배송...  0.125000
# 2612                ['유격', '도', '있고', '때', '도', '묻어있네']  0.000000
# 3395  ['새', '리퍼제품', '이라고', '살때', '는', '확인', '을', '못'...  0.200000
#
# [1925 rows x 5 columns]

# %% [markdown]
# #### statistics1 : 기종 별, 리뷰 카테고리 별 리뷰의 개수

# %%
#카테고리별 전체리뷰갯수
statistics1=pd.pivot_table(df3.drop(df3.columns[[2,4]], axis=1), index = ['type','category'], aggfunc='count')
statistics1
# Out:
#                   token_review
# type    category
# 에어팟 1세대 기능                  70
#         디자인                150
#         배터리 수명              10
#         성능                 111
#         음질                 586
#         조작성                 45
#         착용감                 49
#         품질                 116
#         휴대성                 16
# 에어팟 2세대 기능                 129
#         디자인                351
#         배터리 수명              14
#         성능                 225
#         음질                1373
#         조작성                 36
#         착용감                 97
#         품질                 286
#         휴대성                 20

# %%
#긍정도 평균
statistics1_=pd.pivot_table(add_df.drop(add_df.columns[[2, 3]], axis=1), index = ['type','category'], aggfunc='mean')

# %%
statistics1_
# Out:
#                   positive
# type    category
# 에어팟 1세대 기능        0.893521
#         디자인       0.923919
#         배터리 수명    0.878788
#         성능        0.905500
#         음질        0.912772
#         조작성       0.906815
#         착용감       0.916037
#         품질        0.944222
#         휴대성       0.951389
# 에어팟 2세대 기능        0.933138
#         디자인       0.941952
#         배터리 수명    0.968750
#         성능        0.934699
#         음질        0.921734
#         조작성       0.894987
#         착용감       0.930584
#         품질        0.936678
#         휴대성       0.934524

# %%
# statistics1__ = pd.concat([statistics1_, statistics1], join='outer', axis=1)
# statistics1__

# %% [markdown]
# #### statistics2 : 기종 별 리뷰의 개수

# %%
statistics2=statistics1.groupby('type').sum()
statistics2
# Out:
#          token_review
# type
# 에어팟 1세대          1153
# 에어팟 2세대          2531

# %%
statistics2_=statistics1_.groupby('type').mean()
statistics2_
# Out:
#          positive
# type
# 에어팟 1세대  0.914774
# 에어팟 2세대  0.933005

# %%
# statistics2__ = pd.concat([statistics2_, statistics2], join='outer', axis=1)
# statistics2__

# %% [markdown]
# #### statistics3 : 기종 별, 별점 별 리뷰의 개수

# %%
#전체 별점별 리뷰갯수
statistics3 = pd.pivot_table(add_df.drop(add_df.columns[[1, 4]], axis=1), index = ['type','star'], aggfunc='count')
statistics3
# Out:
#               token_review
# type    star
# 에어팟 1세대 3                7
#         4               55
#         5              484
# 에어팟 2세대 1                4
#         3               12
#         4              110
#         5             1253

# %%
# #전체 별점별 리뷰갯수
# statistics3 = pd.pivot_table(df3.drop(df3.columns[[1, 4]], axis=1), index = ['type','star'], aggfunc='count')
# statistics3

# %%
#긍정도 평균
statistics3_ = pd.pivot_table(add_df.drop(add_df.columns[[1, 3]], axis=1), index = ['type','star'], aggfunc='mean')
statistics3_
# Out:
#               positive
# type    star
# 에어팟 1세대 3     0.485714
#         4     0.712733
#         5     0.946088
# 에어팟 2세대 1     0.126705
#         3     0.513920
#         4     0.708207
#         5     0.954231

# %%
statistics3__ = pd.concat([statistics3_, statistics3], join='outer', axis=1)
statistics3__
# Out:
#               positive  token_review
# type    star
# 에어팟 1세대 3     0.485714             7
#         4     0.712733            55
#         5     0.946088           484
# 에어팟 2세대 1     0.126705             4
#         3     0.513920            12
#         4     0.708207           110
#         5     0.954231          1253

# %% [markdown]
# 위에서 보다시피 부정적인 리뷰의 개수가 매우 적다. 애초에 에어팟을 사용하는 사람들이 부정적인 리뷰를 잘 남기지 않음을 알 수 있다.

# %% [markdown]
# ---

# %% [markdown]
# ## 별점이 5점

# %%
df1=df[df['star']==5][['type','category','token_review', 'positive']]

# %%
df1
# Out:
#          type category                                       token_review  \
# 0     에어팟 1세대       음질  2 세대 로 배송 받았고 철 가루 랑 하얀색 실리콘 케이스 도 잘 받았습니다 역시 ...
# 1     에어팟 1세대       음질  배송 은 4시 이전 주문 당일 발송 으로 다음 날 바로 받았구요 바로 정품 등록 했...
# 2     에어팟 1세대       음질  아이폰 과 아이패드 를 둘 다 사용 하고 있는데 아이폰 에서 음악 을 듣거나 영상 ...
# 4     에어팟 1세대       음질  택배 도 하루 일찍 오고 하자 하나 도 없고 깔끔했어요 뽁뽁이 로 포장 도 해주셔서...
# 5     에어팟 1세대       음질  배송 너무 빨 라서 놀랐어요 금요일 에 주문 해서 다름주에 오겠다 했는데 다음 날 ...
# ...       ...      ...                                                ...
# 3779  에어팟 2세대      착용감                              착용 감 음질 모든 게 너무 다 좋아요
# 3780  에어팟 2세대      착용감  카드 사 할인 까지 받아서 싸게 샀어요 소리 가 너무 좋고 귀 도 편하고 착용 감 ...
# 3781  에어팟 2세대      착용감                  생각 보다 착용 감 이 좋습니다 즐거운 사운드 를 느꼈습니다
# 3782  에어팟 2세대      착용감  우선 이전 에 에어팟 을 써 본적 은 없고 갤럭시 기어 아이콘 2018년 형 을 썼...
# 3785  에어팟 2세대      휴대성                          디자인 도 깔끔하니 세련되고 휴대 성도 좋아요
#
#       positive
# 0     0.625000
# 1     0.769231
# 2     0.680000
# 4     0.444444
# 5     0.200000
# ...        ...
# 3779  0.500000
# 3780  0.625000
# 3781  1.000000
# 3782  0.400000
# 3785  1.000000
#
# [3191 rows x 4 columns]

# %% [markdown]
# ## 별점 5점 에어팟 1세대 음질

# %%
df2=df[(df['star']==5)&(df['category']=='음질')&(df['type']=='에어팟 1세대')][['type','category','token_review', 'positive']]
df2
# Out:
#         type category                                       token_review  \
# 0    에어팟 1세대       음질  2 세대 로 배송 받았고 철 가루 랑 하얀색 실리콘 케이스 도 잘 받았습니다 역시 ...
# 1    에어팟 1세대       음질  배송 은 4시 이전 주문 당일 발송 으로 다음 날 바로 받았구요 바로 정품 등록 했...
# 2    에어팟 1세대       음질  아이폰 과 아이패드 를 둘 다 사용 하고 있는데 아이폰 에서 음악 을 듣거나 영상 ...
# 4    에어팟 1세대       음질  택배 도 하루 일찍 오고 하자 하나 도 없고 깔끔했어요 뽁뽁이 로 포장 도 해주셔서...
# 5    에어팟 1세대       음질  배송 너무 빨 라서 놀랐어요 금요일 에 주문 해서 다름주에 오겠다 했는데 다음 날 ...
# ..       ...      ...                                                ...
# 579  에어팟 1세대       음질                좋아요 \n 사운드 도 좋고 \n 제품 도 이상 없고 잘 왔어요
# 580  에어팟 1세대       음질                          역시 애플 은 믿을 만 합니다 음질 매우 좋음
# 581  에어팟 1세대       음질                             좋습니다 무선 의 편리함 음질 도 좋아요
# 584  에어팟 1세대       음질                                      음질 도 좋구 만족합니다
# 585  에어팟 1세대       음질                        역시 좋아요 에어팟 정말 편하고 음질 도 좋습니다
#
#      positive
# 0    0.625000
# 1    0.769231
# 2    0.680000
# 4    0.444444
# 5    0.200000
# ..        ...
# 579  0.714286
# 580  1.000000
# 581  1.000000
# 584  1.000000
# 585  1.000000
#
# [502 rows x 4 columns]

# %%
#평점은 좋은데 긍정도 낮은 리뷰 삭제
index=df2[df2['positive']<0.7].index
df2=df2.drop(index)

# %%
df2
# Out:
#         type category                                       token_review  \
# 1    에어팟 1세대       음질  배송 은 4시 이전 주문 당일 발송 으로 다음 날 바로 받았구요 바로 정품 등록 했...
# 12   에어팟 1세대       음질  좀 더 일찍 살것을 전 인강 용 으로 걸으며 들을 코드 리스 콩나물 을 구매 했습니...
# 26   에어팟 1세대       음질  배송 도 12일 만에 와 굉장히 빨랐고 제품 도 애플 제품 답 게 신선한 제품 기능...
# 28   에어팟 1세대       음질  얼머전 에 에어팟 구매 하고 신세계 를 맛보았네요 너무 간편하고 음질 도 만족해서 ...
# 32   에어팟 1세대       음질  하이마트 가 혜택 이 많아서 구매 했는데 배송 도 빠르네요 월 오후 주문 이 화 오...
# ..       ...      ...                                                ...
# 579  에어팟 1세대       음질                좋아요 \n 사운드 도 좋고 \n 제품 도 이상 없고 잘 왔어요
# 580  에어팟 1세대       음질                          역시 애플 은 믿을 만 합니다 음질 매우 좋음
# 581  에어팟 1세대       음질                             좋습니다 무선 의 편리함 음질 도 좋아요
# 584  에어팟 1세대       음질                                      음질 도 좋구 만족합니다
# 585  에어팟 1세대       음질                        역시 좋아요 에어팟 정말 편하고 음질 도 좋습니다
#
#      positive
# 1    0.769231
# 12   1.000000
# 26   0.777778
# 28   0.777778
# 32   0.750000
# ..        ...
# 579  0.714286
# 580  1.000000
# 581  1.000000
# 584  1.000000
# 585  1.000000
#
# [225 rows x 4 columns]

# %%
df2['positive'].mean(axis=0)
# Out:
# 0.9241406656544278

# %% [markdown]
# ## 별점 5점 에어팟 2세대(유선,무선) 음질

# %%
df3=df[(df['star']==5)&(df['category']=='음질')&(df['type']=='에어팟 2세대(유선)')|(df['type']=='에어팟 2세대')][['type','category','token_review', 'positive']]
df3
# Out:
#              type category                                       token_review  \
# 1108  에어팟 2세대(유선)       음질  안드로이드 폰 만 사용 중이 예요 그래서 구매 를 망설였는데 연결 잘 되고 소리 도...
# 1109  에어팟 2세대(유선)       음질  가격 에어팟 2 요즘 에 그냥 다 이 가격 대 인것 같아 싸게 산것 같진 않고 그냥...
# 1110  에어팟 2세대(유선)       음질  감사합니다 판매 자 분 159300원 에 풀어 준 옥션 도 역시 넘 이뻐요 음질 도...
# 1111  에어팟 2세대(유선)       음질  19년 도 11월 제품 이고 정품 등록 바로 되고 \n 하자 없이 잘 작동 합니다 ...
# 1112  에어팟 2세대(유선)       음질  19년 도 11월 제품 이고 정품 등록 바로 되고 \n 하자 없이 잘 작동 합니다 ...
# ...           ...      ...                                                ...
# 3781      에어팟 2세대      착용감                  생각 보다 착용 감 이 좋습니다 즐거운 사운드 를 느꼈습니다
# 3782      에어팟 2세대      착용감  우선 이전 에 에어팟 을 써 본적 은 없고 갤럭시 기어 아이콘 2018년 형 을 썼...
# 3783      에어팟 2세대      휴대성  휴대 하기 편하고 애플 기기 사이 의 호환성 이 좋은 무선 이어폰 이 필요해서 에어...
# 3784      에어팟 2세대      휴대성              휴대 하기도 좋고 음질 도 좋은데 떨어져서 잊어 버릴까 불안 하네요
# 3785      에어팟 2세대      휴대성                          디자인 도 깔끔하니 세련되고 휴대 성도 좋아요
#
#       positive
# 1108  0.533333
# 1109  0.387097
# 1110  0.500000
# 1111  0.422222
# 1112  0.422222
# ...        ...
# 3781  1.000000
# 3782  0.400000
# 3783  0.421053
# 3784  0.285714
# 3785  1.000000
#
# [1394 rows x 4 columns]

# %%
#평점은 좋은데 긍정도 낮은 리뷰 삭제
index=df3[df3['positive']<0.7].index
df3=df3.drop(index)

# %%
df3
# Out:
#              type category                                       token_review  \
# 1113  에어팟 2세대(유선)       음질  제품 매우 만족 1 세대 유저 로서 2 세대 비슷하다라는 의견 있으나 저 는 음질 ...
# 1122  에어팟 2세대(유선)       음질  정 품일 까 긴가 민가 하다가 리뷰 보고 구매 했는데 정말로 정 품이더라고요 제품 ...
# 1132  에어팟 2세대(유선)       음질  휴대폰 기 종 LG V 30 인데요 호환 잘 되구요 \n 예쁜 케이스 끼우는 맛 도...
# 1150  에어팟 2세대(유선)       음질  선물 용 인데 아직 개봉 전이 에요 좋아하면 좋겠 네 요정 품 등록 이랑 잘 되면 ...
# 1158  에어팟 2세대(유선)       음질  요즘 에어팟 인기 많잖아요 그래서 구입 했는데 정말 좋아요 인 싸 된 느낌 음질 도...
# ...           ...      ...                                                ...
# 3774      에어팟 2세대      착용감  뱅앤울룹슨 E 8 을 사용 했었습니다 E 8 과 비교 하여 착용 감 이 월등히 우수...
# 3776      에어팟 2세대      착용감                               착용 감도 좋고 정품 이라 더 좋아요
# 3778      에어팟 2세대      착용감               배송 엄청 빨리 왔네요 무선 이라 엄청 편하네요 착용 감도 좋구요
# 3781      에어팟 2세대      착용감                  생각 보다 착용 감 이 좋습니다 즐거운 사운드 를 느꼈습니다
# 3785      에어팟 2세대      휴대성                          디자인 도 깔끔하니 세련되고 휴대 성도 좋아요
#
#       positive
# 1113  0.833333
# 1122  0.714286
# 1132  0.818182
# 1150  0.736842
# 1158  0.777778
# ...        ...
# 3774  0.750000
# 3776  1.000000
# 3778  1.000000
# 3781  1.000000
# 3785  1.000000
#
# [798 rows x 4 columns]

# %%
df3['positive'].mean(axis=0)
# Out:
# 0.9289329490157604
